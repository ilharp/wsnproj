# %% [markdown]
# # 数据分析
#
# ## 环境准备
#
# 数据分析环境：Anaconda + Python 3.8

# %%
# %pip install matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %% [markdown]
# ## 导入数据

# %%
err_x = range(1, 33)
err_y = [21797, 0, -1, 4, 1, -5, 3, -1, -1, -1, 1, -1, 3, 3, -3, 3, -4, 3, 1, 3, -4, 1, 1, -3, 0, 6, -1, -5, 1, 3, -1, 0]

merr_x = range(1, 32)
merr_y = [0, -1, 4, 1, -5, 3, -1, -1, -1, 1, -1, 3, 3, -3, 3, -4, 3, 1, 3, -4, 1, 1, -3, 0, 6, -1, -5, 1, 3, -1, 0]

time_x = range(1, 27)
time_y1 = [51172, 54168, 57167, 60170, 63168, 631, 3630, 6632, 9629, 12629, 15631, 18635, 21634, 24632, 27635, 30636, 33632, 36632, 39633, 42639, 45638, 48642, 51632, 54636, 57630, 60633]
time_y2 = [51169, 54169, 57160, 60172, 63164, 631, 3632, 6632, 9629, 12627, 15631, 18634, 21633, 24632, 27634, 30635, 33632, 36632, 39636, 42639, 45639, 48639, 51629, 54635, 57630, 60634]

# %% [markdown]
# ## 绘图
#
# ### 配置环境

# %%
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.size'] = 18
mpl.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 开始绘图

# %%
plt.figure(figsize=(20, 10))
plt.title("TPSN 误差")
plt.xlabel("测量组")
plt.ylabel("误差（ms）")
plt.xticks(err_x)

plt.plot(err_x, err_y, color = 'r', marker = 'o', label = "误差（ms）")
plt.legend()
plt.grid()

# %%
plt.figure(figsize=(20, 10))
plt.title("TPSN 误差（校准后）")
plt.xlabel("测量组")
plt.ylabel("误差（ms）")
plt.xticks(err_x)

plt.plot(merr_x, merr_y, color = 'r', marker = 'o', label = "误差（ms）")
plt.legend()
plt.grid()

# %%
plt.figure(figsize=(20, 10))
plt.title("TPSN 报时")
plt.xlabel("测量组")
plt.ylabel("时刻（ms）")
plt.xticks(err_x)

plt.plot(time_x, time_y1, color='r', marker='o', label="节点 A")
plt.plot(time_x, time_y2, color='b', marker='x', dashes=[10, 10], label="节点 B")
plt.legend()
plt.grid()
